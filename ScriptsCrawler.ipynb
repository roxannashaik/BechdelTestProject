# %%
import os
from bs4 import BeautifulSoup
import xml.etree.ElementTree as ET
import time
import pandas as pd

# %%
path = './script2'

files = []

# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if '.txt' in file:
            files.append(os.path.join(r, file))

# %%
def extract_name(url):
    s = url.strip('.html.txt').strip('./script').split('-')
    if s[-1].lower() == "the":
        s[-2] = s[-2][:-1]
        s = ["The"] + s[:-1]
    return " ".join(s)
#s = name.split()
  #  if(s[0].lower() =="the"):
   #     return  "-".join(s[1:]) +",-The"+".html"
   # return "-".join(s)+".html"

# %%
scripts = pd.DataFrame(columns = ['name','info', 'convo'])

# %%
count = 0
nonnone = 0 
for f in files:
    #print(f)
    fi = open(f,'r')
    #data = fi.read()
    data = fi.readlines()
    l = 0
    name = extract_name(f)#f.strip('.html.txt').split('/')[-1].upper()
    #print("name: "+ str(name))
    #print("data: "+ str(data))
    data=data[196:len(data)-54]
    data = "".join(data)
    #print(data)
#    for ind in range(len(data)):
      #  if data[ind] in (name):
       #     l = ind
          #  print(data[ind])
   # print(l)
    fi.close()
    if(len(data)> 200):
        convo = []
        info = []
        #print(data)
        
        soup = BeautifulSoup(data,'lxml')
        #print(soup.find_all("p"))
        p = soup.find_all("p")
        #print(name)
        #print()
        #print()
        #print(p)
        if(p == []):# Case 1
            b = soup.find_all("b")#contains character names/locations
            convo = soup.get_text() # conversations
            info = []
            for bleh in b:
                info.append(''.join(bleh.findAll(text=True)).strip())
            info = " ".join(info)  
            convo = ' '.join(convo)
        else:
            charName = soup.find_all('p', attrs={'class' : 'CHARACTERNAME'})
            action = soup.find_all('p', attrs={'class' : 'ACTION'})
            para = soup.find_all('p', attrs={'class':'PARENTHETICAL'})
            #comperable to conversations
            dialog = soup.find_all('p', attrs={'class': 'DIALOG'})
            scene = soup.find_all('p', attrs={'class':'SCENEHEADING'})
            if(not charName == [] and not action == [] and not para == []): # Case 3
                info = []
                convo = []
                for bleh in charName + action + para:
                    info.append(''.join(bleh.findAll(text=True)).strip())
                for pleh in dialog + scene:
                    convo.append(''.join(pleh.findAll(text=True)).strip())
                info = " ".join(info)  
                convo = ' '.join(convo)
            else:
                b = soup.find_all('b')
                p = soup.find_all('p')
                info = []
                for bleh in b:
                    info.append(''.join(bleh.findAll(text=True)).strip())
                info = ' '.join(info)
                convo = []
                for pleh in p:
                    convo.append(''.join(pleh.findAll(text=True)).strip())
                convo = ''.join(convo)
                #text = soup.b.get_sibling()
                #print(b)
                #print(p)
                if(p == []):
                    print("here")
                   # b_el = record_el.find('b',text='Title:')
                    convo = []
                    b = soup.find_all('b')
                    print(b)
                    print(soup)
                    for x in b:
                        s = str(x.next_sibling.string).split('\n')
                        r = []
                        for y in s:
                            r.append(y.strip())
                            #print(y)
                            #print(y.strip())
                            #print(y)
                        r = [x for x in r if x]
                        convo.extend(r)
                    convo = ' '.join(convo)
        count +=1
        scripts.loc[count]=[name, info, convo]
                #scripts= scripts.append([info,convo])
                #print(b.next_sibling)
                #print(soup.text)
                #print(name)
            #print()
            #print(name)
            #print()
            #print(convo)
            #print(info)
            
               # print(soup.p)
        #txt = soup.text
       # print(txt)
        #for b1 in b:
          #  print(b1.string.strip("<b>"))
            #print(b1.next_sibling)
   # count+=1
    #if(count ==1):
     #   break
        #tag = soup.p
        #css_soup = BeautifulSoup('<p class="action"></p>')
        #css_soup.p['class']
        # ["body", "strikeout"]
        #print(tag.attrs)
print(count)
print(nonnone)
# Out:
# 655
# 0

# %%
import pandas as pd
a = pd.DataFrame({'A' : ['a','b']})
b = pd.DataFrame({'A' : [1,'b']})
pd.concat([a,b])

# %%
scripts
# Out:
#                                 name  \
# 1                               They
# 2                                8MM
# 3                 The Lincoln Lawyer
# 4                          Prometheu
# 5                         ParaNorman
# 6                          Fair Game
# 7                  Water for Elephan
# 8                               Dune
# 9                   Sex and the City
# 10              The Butterfly Effect
# 11                          Catwoman
# 12                      Garden State
# 13                The Blues Brothers
# 14                     Jerry Maguire
# 15                        Adaptation
# 16                          The Debt
# 17                      The Haunting
# 18                    The Bling Ring
# 19                      Frankenstein
# 20                The Breakfast Club
# 21                  30 Minutes or Le
# 22                     Event Horizon
# 23                       Cherry Fall
# 24                   The Descendants
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:stat170@postgres/stat170a', client_encoding='utf8', pool_pre_ping=True)

scripts.to_sql("scriptsData", con = engine,
                   if_exists = 'replace', index = False)

# %%
titleakas = pd.read_sql_query('SELECT titleid, region from titleakas;',con=engine)
titlebasics = pd.read_sql_query('SELECT * from titlebasics as t, bechdal_test as b where t.tconst = b.imdb', con=engine) 
merged = pd.merge(titlebasics, titleakas, left_on='imdb', right_on='titleid')
merged = merged[merged['region'] == 'US'].drop_duplicates()

# %%
m = pd.merge(merged, scripts, left_on='title',right_on = 'name') #titles with the in it wont match
# Out:
#         tconst     titletype                                     primarytitle  \
# 0    tt0021884         movie                                     Frankenstein
# 1    tt0023427         movie                                         Scarface
# 2    tt0086250         movie                                         Scarface
# 3    tt0024216         movie                                        King Kong
# 4    tt0360717         movie                                        King Kong
# 5    tt0026071         movie                                    Anna Karenina
# 6    tt0029162         movie                                     Lost Horizon
# 7    tt0031725         movie                                        Ninotchka
# 8    tt0032599         movie                                  His Girl Friday
# 9    tt0032943         movie                              Pride and Prejudice
# 10   tt0112130  tvMiniSeries                              Pride and Prejudice
# ...

# %%
finData = pd.read_sql_query('SELECT * from \"Numbers\"', con=engine)

# %%
finData
pd.merge(merged, finData, left_on='title',right_on = 'Title').drop_duplicates() #titles with the in it wont match

#pd.read_sql_query('SELECT * from \"Numbers\" as n, ', con=engine)
# Out:
#          tconst titletype                                       primarytitle  \
# 0     tt0023753     movie                                Alice in Wonderland
# 2     tt0043274     movie                                Alice in Wonderland
# 4     tt1014759     movie                                Alice in Wonderland
# 6     tt0024216     movie                                          King Kong
# 8     tt0360717     movie                                          King Kong
# 10    tt0036323     movie                                             Sahara
# 67    tt0038348     movie                               Beauty and the Beast
# 124   tt0101414     movie                               Beauty and the Beast
# 181   tt2771200     movie                               Beauty and the Beast
# 238   tt0070608     movie                                         Robin Hood
# 240   tt0955308     movie                                         Robin Hood
# ...

# %%
merged.drop_duplicates()
# Out:
#            tconst titletype  \
# 21      tt0000012     short
# 31      tt0000014     short
# 50      tt0000091     short
# 73      tt0000211     short
# 87      tt0000230     short
# 100     tt0000246     short
# 110     tt0000272     short
# 117     tt0000300     short
# 132     tt0000306     short
# 154     tt0000413     short
# 165     tt0000417     short
# 203     tt0000439     short
# 220     tt0000455     short
# 240     tt0000554     short
# 243     tt0000567     short
# 261     tt0001009     short
# 266     tt0002101     movie
# 270     tt0002281     short
# 274     tt0003424     short
# 285     tt0003973     movie
# 287     tt0004972     movie
# 321     tt0006745     movie
# 324     tt0006864     movie
# 352     tt0007361     movie
# 356     tt0007507     short
# 387     tt0008443     movie
# 395     tt0008489     movie
# 402     tt0008499     movie
# 411     tt0008519     movie
# 417     tt0008652     movie
# ...           ...       ...
# 176741  tt6857166     movie
# ...
